# %% [markdown]
# <span style="color:red">Parice for pyspark</span>

# %%
# %sql
create catalog if not exists catalog_usecase_partice

# %%
csv_df1=spark.read.csv("dbfs:///Volumes/catalog_usecase_partice/usecase_partice_schema/usercase_volmue/custs",)
csv_df2=csv_df1.toDF("id","fname","Lname","age","proffession")
csv_df2.show(10)
print(csv_df1.printSchema())
print(csv_df2.printSchema())
print(csv_df1.schema)
print(csv_df2.schema)
display(csv_df1)

# %%
csv_df1=spark.read.csv("dbfs:///Volumes/catalog_usecase_partice/usecase_partice_schema/usercase_volmue/custs_header",header=True)
csv_df1.show(20)
display(csv_df1)
print(csv_df1.printSchema())
print(csv_df1.schema)
