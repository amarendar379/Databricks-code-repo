# %% [markdown]
# # **USECASE TASKS**
#
# you can use **or (__) double underscore for first and last of line or senttence to appear in bold
# ## *Day one usecase taks*
#
# ####Task1: Document the Notebook Using mark down %md
# you can use * or (_) singel under score  for first and last of line or senttence to appear in Italic
#
#
# My name is <span style="color:blue;">Amarendar Reddy</span>
#
#
# ![Batch36 Team](https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %%
# %sql

CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics
